# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style = "darkgrid")

# %%
import numpy as np

x = np.array([0,2,3,4,5,6,7,8,9,60,90])
y = np.sin(x)
sns.lineplot(x=x,y=y)
plt.title('Beautiful Line plot')
# Out:
# Text(0.5, 1.0, 'Beautiful Line plot')
