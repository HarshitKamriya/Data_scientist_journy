# %%
import matplotlib.pyplot as plt

# %%
data = [34,54,75,57,97,85,
        85,34,43,64,65,85,
        2,5,24,76,53,90,
        54,57,16,25,36,36]

# %%
plt.hist(data,bins=10,edgecolor = 'black')
# Out:
# (array([2., 1., 2., 4., 1., 5., 2., 2., 3., 2.]),
#  array([ 2. , 11.5, 21. , 30.5, 40. , 49.5, 59. , 68.5, 78. , 87.5, 97. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,bins=[10,20,30,40,60,100],edgecolor = 'black')
# Out:
# (array([1., 2., 4., 6., 9.]),
#  array([ 10.,  20.,  30.,  40.,  60., 100.]),
#  <BarContainer object of 5 artists>)

# %%
ages = [
    34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
    25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
    44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
    23, 48, 29, 19, 18, 17, 32, 10, 16, 31,
    37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
    33, 26, 23, 36, 10, 39, 21, 26, 33, 39,
    25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
    33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
    27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
    30, 19, 22, 26, 26, 15, 32, 32, 30, 27
]
bins = [10,20,30,40,50,60,70]
plt.hist(ages,bins = bins,edgecolor = 'black')
plt.title("Age Distribution of Youtube Viewers")
plt.xlabel("Age Group")
plt.ylabel('Number of Viewers')
plt.grid(True,linestyle = '--',alpha  =  0.5)

# %%
import numpy as np
ages = [
    34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
    25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
    44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
    23, 48, 29, 19, 18, 17, 32, 10, 16, 31,
    37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
    33, 26, 23, 36, 10, 39, 21, 26, 33, 39,
    25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
    33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
    27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
    30, 19, 22, 26, 26, 15, 32, 32, 30, 27
]
bins = [10,20,30,40,50,60,70]
plt.hist(ages,bins = bins,edgecolor = 'black')
plt.axvline(np.mean(ages),color = 'red',linestyle = '--',linewidth = 2, label = 'Average Age')
plt.legend()
plt.title("Age Distribution with Mean line")
plt.xlabel("Age Group")
plt.ylabel('Number of Viewers')
plt.grid(True,linestyle = '--',alpha  =  0.5)
