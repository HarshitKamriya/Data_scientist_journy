# %%
import pandas as pd

# %%
df = pd.read_csv("data1.csv")

# %%
df
# Out:
#                 Actor             film  year          Genre  \
# 0      Shah Rukh Khan           Pathan  2016         Action
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 7        Akshay Kumar             War   2022         Action
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
#
#     BoxOffice(INR Cror  IMD
# 0                 1050  7.2
# 1                  565  6.0
# 2                 2024  8.4
# 3                  431  5.6
# 4                  585  7.0
# 5                  111  8.3
# 6                  475  7.5
# ...

# %%
df.sort_values("year")
# Out:
#                 Actor             film  year          Genre  \
# 0      Shah Rukh Khan           Pathan  2016         Action
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 7        Akshay Kumar             War   2022         Action
#
#     BoxOffice(INR Cror  IMD
# 0                 1050  7.2
# 8                  266  7.0
# 2                 2024  8.4
# 3                  431  5.6
# 4                  585  7.0
# 9                  201  5.9
# 5                  111  8.3
# ...

# %%
df.sort_values("year",ascending = False)
# Out:
#                 Actor             film  year          Genre  \
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 7        Akshay Kumar             War   2022         Action
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 0      Shah Rukh Khan           Pathan  2016         Action
#
#     BoxOffice(INR Cror  IMD
# 1                  565  6.0
# 7                  318  6.5
# 5                  111  8.3
# 6                  475  7.5
# 10                 342  8.2
# 2                 2024  8.4
# 3                  431  5.6
# ...

# %%
df = df.sort_values(["year","IMD"])

# %%
df2 = df.sort_values(["year","IMD"]).copy()

# %%
df
# Out:
#                 Actor             film  year          Genre  \
# 0      Shah Rukh Khan           Pathan  2016         Action
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 7        Akshay Kumar             War   2022         Action
#
#     BoxOffice(INR Cror  IMD
# 0                 1050  7.2
# 8                  266  7.0
# 3                  431  5.6
# 9                  201  5.9
# 4                  585  7.0
# 2                 2024  8.4
# 6                  475  7.5
# ...

# %%
df.reset_index()
# Out:
#     index              Actor             film  year          Genre  \
# 0       0     Shah Rukh Khan           Pathan  2016         Action
# 1       8      Kartik Aaryan       Good Newwz  2017         Comedy
# 2       3      Ranveer Singh       Brahmastra  2018        Fantasy
# 3       9       Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 4       4  Ayushman Khurrana        Padmaavat  2018     Historical
# 5       2      Ranbir Kapoor           Dangal  2018      Biography
# 6       6     Hrithik Roshan           Stree   2019  Horror Comedy
# 7      10      Vicky Kaushal              URI  2019         Action
# 8       5      Ranjkuman Rao        Andhadhun  2019       Thriller
# 9       1        Salman Khan  Tiger Zinda Hai  2022         Action
# 10      7       Akshay Kumar             War   2022         Action
#
#     BoxOffice(INR Cror  IMD
# 0                 1050  7.2
# 1                  266  7.0
# 2                  431  5.6
# 3                  201  5.9
# ...

# %%
df2
# Out:
#                 Actor             film  year          Genre  \
# 0      Shah Rukh Khan           Pathan  2016         Action
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 7        Akshay Kumar             War   2022         Action
#
#     BoxOffice(INR Cror  IMD
# 0                 1050  7.2
# 8                  266  7.0
# 3                  431  5.6
# 9                  201  5.9
# 4                  585  7.0
# 2                 2024  8.4
# 6                  475  7.5
# ...

# %%
df2.reset_index(drop = True, inplace = True)

# %%
df2
# Out:
#                 Actor             film  year          Genre  \
# 0      Shah Rukh Khan           Pathan  2016         Action
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 7        Akshay Kumar             War   2022         Action
#
#     BoxOffice(INR Cror  IMD
# 0                 1050  7.2
# 8                  266  7.0
# 3                  431  5.6
# 9                  201  5.9
# 4                  585  7.0
# 2                 2024  8.4
# 6                  475  7.5
# ...

# %%
df2.sort_index()
# Out:
#                 Actor             film  year          Genre  \
# 0      Shah Rukh Khan           Pathan  2016         Action
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 7        Akshay Kumar             War   2022         Action
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
#
#     BoxOffice(INR Cror  IMD
# 0                 1050  7.2
# 1                  565  6.0
# 2                 2024  8.4
# 3                  431  5.6
# 4                  585  7.0
# 5                  111  8.3
# 6                  475  7.5
# ...

# %%
df2["Rank"] = df2["IMD"].rank(ascending = False,method = "dense")

# %%
df2
# Out:
#                 Actor             film  year          Genre  \
# 0      Shah Rukh Khan           Pathan  2016         Action
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 7        Akshay Kumar             War   2022         Action
#
#     BoxOffice(INR Cror  IMD  Rank
# 0                 1050  7.2   5.0
# 8                  266  7.0   6.0
# 3                  431  5.6  10.0
# 9                  201  5.9   9.0
# 4                  585  7.0   6.0
# ...

# %%
# df = df["film","year","Genre","Actor","IMD","BoxOffice(INR Cror"]zzzz

# %%
df
# Out:
#                 Actor             film  year          Genre  \
# 0      Shah Rukh Khan           Pathan  2016         Action
# 8       Kartik Aaryan       Good Newwz  2017         Comedy
# 3       Ranveer Singh       Brahmastra  2018        Fantasy
# 9        Varun Dhawan  Bhool Bhulaiyaa  2018  Horror Comedy
# 4   Ayushman Khurrana        Padmaavat  2018     Historical
# 2       Ranbir Kapoor           Dangal  2018      Biography
# 6      Hrithik Roshan           Stree   2019  Horror Comedy
# 10      Vicky Kaushal              URI  2019         Action
# 5       Ranjkuman Rao        Andhadhun  2019       Thriller
# 1         Salman Khan  Tiger Zinda Hai  2022         Action
# 7        Akshay Kumar             War   2022         Action
#
#     BoxOffice(INR Cror  IMD
# 0                 1050  7.2
# 8                  266  7.0
# 3                  431  5.6
# 9                  201  5.9
# 4                  585  7.0
# 2                 2024  8.4
# 6                  475  7.5
# ...

# %%
cols = ["film"] + [col for col in df.coulmns if col != "film"]
df  = df[cols]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3172\4010294483.py in ?()
# ----> 1 cols = ["film"] + [col for col in df.coulmns if col != "film"]
#       2 df  = df[cols]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'coulmns'
